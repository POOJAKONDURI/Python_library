# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv'
data = pd.read_csv(url)

plt.figure(figsize=(10, 6))
sns.boxplot(x='lifeExp', y='continent', data=data)

# Add titles and labels
plt.title('life expectancy')
plt.xlabel('continenet')
plt.ylabel('life expectency fealted to continent')

# Show the plot
plt.show()

# %% [markdown]
# Write a program to draw box plot of life expectancy by continent for a data set given in a
# url
# https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapmind
# er-FiveYearData.csv
