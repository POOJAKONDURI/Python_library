# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'
data = pd.read_csv(url)

plt.figure(figsize=(10, 6))
sns.swarmplot(x='total_bill', y='size', data=data)

# Add titles and labels
plt.title('total_bill')
plt.xlabel('size')
plt.ylabel('total bill against size')

# Show the plot
plt.show()
# Out:
# c:\Users\pooja konduri\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\pooja konduri\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
