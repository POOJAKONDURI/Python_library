# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [4,5,6]

plt.plot(x,y)
# current axis
print(plt.axis())
#set x limits
plt.xlim(1,3)
#set y limits
plt.ylim(1,6)
plt.show()

,
# Out:
# (np.float64(0.9), np.float64(3.1), np.float64(3.9), np.float64(6.1))
# ''
