# %%
import matplotlib.pyplot as plt
x  = [1,2,3,4]
y  = [6,7,8,9]
z  = [11,2,13,10]
plt.plot(x,y)
plt.plot(x,z)
plt.legend(["line1","line2"])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("multi line in same plot") 
plt.show()
