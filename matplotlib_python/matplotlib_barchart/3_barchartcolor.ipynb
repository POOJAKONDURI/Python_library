# %%
import matplotlib.pyplot as plt
Programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(Programming_languages,Popularity,color = "red")
plt.show()
