# %%
import matplotlib.pyplot as plt
Programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
tick_label = ['1','2','3','4','5','6']
c = ['red','hotpink','blue']
plt.bar(range(len(Programming_languages)),Popularity,color = c)

plt.show()
