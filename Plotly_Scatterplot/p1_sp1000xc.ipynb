# %%
import plotly.express as px
import pandas as pd
import numpy as np
x  = np.random.rand(1000)
y = np.random.rand(1000)
df = pd.DataFrame({'X':x,'Y':y})

fig = px.scatter(df,x='X',y='Y', title='Scatter Plot of Random 1000 Coordinates')
fig.show()
